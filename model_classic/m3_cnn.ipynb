# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import matplotlib.pyplot as plt


df=pd.read_csv("../data_formatted/training_dataset.csv",low_memory=False)
df.match_date = df.match_date.apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))

df = df.dropna()
df = df[(df.player1_plays > 10) & (df.player2_plays>10)]
df.shape
# Out:
# (35572, 36)

# %%
from sklearn.model_selection import train_test_split

X = df[["player1_name", "player1_age", "player1_atprank", "player1_plays", "player1_wins", "player1_losses", "player1_elo", "player1_mean_serve_rating", "player1_mean_atp_adversary", "player1_height", "player1_weight", "player1_oddsB365",
        "player2_name", "player2_age", "player2_atprank", "player2_plays", "player2_wins", "player2_losses", "player2_elo", "player2_mean_serve_rating", "player2_mean_atp_adversary", "player2_height", "player2_weight", "player2_oddsB365",
        "match_date","winner_player1"]]
y = df.winner_player1
#y = np.where(((df.player1_oddsB365 > df.player2_oddsB365) & (df.winner_player1==1)) | ((df.player1_oddsB365 < df.player2_oddsB365) & (df.winner_player1==0)),1,0)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)# shuffle=False)

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([24917, 10655], dtype=int64))

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler 

col_to_drop = ["player1_name", "player2_name", "match_date","winner_player1"]
X_train_filtered = X_train.drop(col_to_drop,axis=1)
X_test_filtered = X_test.drop(col_to_drop,axis=1)

scaler = MinMaxScaler()
scaler.fit(X_train_filtered[["player1_plays", "player2_plays","player1_elo","player2_elo"]])
X_train_filtered[["player1_plays","player2_plays", "player1_elo","player2_elo"]] = scaler.transform(X_train_filtered[["player1_plays","player2_plays", "player1_elo","player2_elo"]])
X_test_filtered[["player1_plays","player2_plays", "player1_elo","player2_elo"]] = scaler.transform(X_test_filtered[["player1_plays","player2_plays", "player1_elo","player2_elo"]])

#scaler = StandardScaler()
#scaler.fit(X_train_filtered)
#X_train_filtered = scaler.transform(X_train_filtered)
#X_test_filtered = scaler.transform(X_test_filtered)

X_train_filtered = pd.DataFrame(X_train_filtered)
X_test_filtered = pd.DataFrame(X_test_filtered)

X_train_filtered.head()
# Out:
#        player1_age  player1_atprank  player1_plays  player1_wins  \
# 39723    23.575633             22.0       0.101222            71
# 14036    34.184805             59.0       0.176265           107
# 33806    33.722108              2.0       0.794939           791
# 14371    30.573580             32.0       0.263525           209
# 14472    21.579740             14.0       0.119546            80
#
#        player1_losses  player1_elo  player1_mean_serve_rating  \
# 39723              56     0.308011                 258.560963
# 14036             106     0.175721                 248.840068
# 33806             131     0.657305                 278.417755
# 14371             104     0.304328                 264.708750
# 14472              68     0.209484                 264.836977
#
#        player1_mean_atp_adversary  player1_height  player1_weight  ...  \
# 39723                   62.169769           185.0            84.0  ...
# 14036                   60.869732           178.0            74.0  ...
# 33806                   38.423510           185.0            85.0  ...
# 14371                   68.719751           191.0            88.0  ...
# 14472                   64.498897           196.0            91.0  ...
#
#        player2_atprank  player2_plays  player2_wins  player2_losses  \
# 39723             86.0       0.040905            23              35
# 14036             22.0       0.197563           124             114
# 33806             71.0       0.501305           311             276
# 14371             56.0       0.179286           110             107
# 14472             32.0       0.083551            52              55
#
#        player2_elo  player2_mean_serve_rating  player2_mean_atp_adversary  \
# 39723     0.167189                 277.852632                   79.705590
# 14036     0.238708                 253.224824                   66.041596
# 33806     0.184598                 260.241466                   79.946392
# 14371     0.216907                 248.809312                   60.499108
# 14472     0.254078                 270.109890                   82.774650
#
#        player2_height  player2_weight  player2_oddsB365
# 39723           191.0            87.0              3.25
# 14036           183.0            73.0              1.57
# 33806           185.0            78.0             10.00
# 14371           178.0            74.0              2.62
# 14472           183.0            86.0              1.66
#
# [5 rows x 22 columns]

# %%
import keras
from keras.layers import Dense
import matplotlib.pyplot as plt

def custom_loss(odds1, odds2):
    def loss(y_true, y_pred):
        if (y_true == 1):
            delta = abs((y_pred - y_true))*odds1
        else:
            delta = abs((y_pred - y_true))*odds2
        return delta
    return loss

model = keras.Sequential()
model.add(Dense(X_train_filtered.shape[1], activation='relu'))
model.add(Dense(X_train_filtered.shape[1], activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_filtered, y_train,                        # Training dataset
                        epochs = 30,                         # Number of epochs
                        batch_size = 50,                     # Len of batch
                        validation_data=(X_test_filtered, y_test))    # Validation dataset

plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')
plt.show()
# Out:
# Epoch 1/30
# 570/570 [==============================] - 1s 891us/step - loss: 0.8447 - accuracy: 0.6050 - val_loss: 0.6585 - val_accuracy: 0.6410
# Epoch 2/30
# 570/570 [==============================] - 0s 718us/step - loss: 0.6659 - accuracy: 0.6273 - val_loss: 0.6559 - val_accuracy: 0.6302
# Epoch 3/30
# 570/570 [==============================] - 0s 724us/step - loss: 0.6506 - accuracy: 0.6333 - val_loss: 0.7040 - val_accuracy: 0.5911
# Epoch 4/30
# 570/570 [==============================] - 0s 717us/step - loss: 0.6381 - accuracy: 0.6438 - val_loss: 0.6398 - val_accuracy: 0.6384
# Epoch 5/30
# 570/570 [==============================] - 0s 803us/step - loss: 0.6304 - accuracy: 0.6479 - val_loss: 0.6502 - val_accuracy: 0.6349
# Epoch 6/30
# 570/570 [==============================] - 0s 743us/step - loss: 0.6241 - accuracy: 0.6501 - val_loss: 0.7062 - val_accuracy: 0.5969
# Epoch 7/30
# 570/570 [==============================] - 0s 729us/step - loss: 0.6213 - accuracy: 0.6525 - val_loss: 0.6105 - val_accuracy: 0.6554
# Epoch 8/30
# 570/570 [==============================] - 0s 715us/step - loss: 0.6130 - accuracy: 0.6593 - val_loss: 0.6133 - val_accuracy: 0.6578
# Epoch 9/30
# 570/570 [==============================] - 0s 710us/step - loss: 0.6126 - accuracy: 0.6582 - val_loss: 0.6102 - val_accuracy: 0.6593
# Epoch 10/30
# 570/570 [==============================] - 0s 724us/step - loss: 0.6111 - accuracy: 0.6605 - val_loss: 0.6146 - val_accuracy: 0.6540
# Epoch 11/30
# 570/570 [==============================] - 0s 716us/step - loss: 0.6043 - accuracy: 0.6655 - val_loss: 0.5998 - val_accuracy: 0.6715
# Epoch 12/30
# 570/570 [==============================] - 0s 711us/step - loss: 0.6011 - accuracy: 0.6665 - val_loss: 0.6008 - val_accuracy: 0.6749
# Epoch 13/30
# 570/570 [==============================] - 0s 706us/step - loss: 0.5978 - accuracy: 0.6691 - val_loss: 0.5948 - val_accuracy: 0.6745
# Epoch 14/30
# 570/570 [==============================] - 0s 709us/step - loss: 0.5969 - accuracy: 0.6727 - val_loss: 0.5902 - val_accuracy: 0.6811
# Epoch 15/30
# 570/570 [==============================] - 0s 715us/step - loss: 0.5937 - accuracy: 0.6736 - val_loss: 0.5919 - val_accuracy: 0.6753
# Epoch 16/30
# 570/570 [==============================] - 0s 725us/step - loss: 0.5932 - accuracy: 0.6758 - val_loss: 0.5970 - val_accuracy: 0.6752
# Epoch 17/30
# 570/570 [==============================] - 0s 730us/step - loss: 0.5936 - accuracy: 0.6749 - val_loss: 0.5861 - val_accuracy: 0.6839
# Epoch 18/30
# 570/570 [==============================] - 0s 737us/step - loss: 0.5944 - accuracy: 0.6753 - val_loss: 0.5871 - val_accuracy: 0.6805
# Epoch 19/30
# 570/570 [==============================] - 0s 716us/step - loss: 0.5899 - accuracy: 0.6798 - val_loss: 0.5937 - val_accuracy: 0.6749
# Epoch 20/30
# 570/570 [==============================] - 0s 721us/step - loss: 0.5913 - accuracy: 0.6770 - val_loss: 0.5832 - val_accuracy: 0.6869
# Epoch 21/30
# 570/570 [==============================] - 0s 723us/step - loss: 0.5901 - accuracy: 0.6808 - val_loss: 0.5821 - val_accuracy: 0.6880
# Epoch 22/30
# 570/570 [==============================] - 0s 751us/step - loss: 0.5905 - accuracy: 0.6792 - val_loss: 0.5907 - val_accuracy: 0.6825
# Epoch 23/30
# 570/570 [==============================] - 0s 720us/step - loss: 0.5905 - accuracy: 0.6786 - val_loss: 0.5906 - val_accuracy: 0.6784
# Epoch 24/30
# 570/570 [==============================] - 0s 724us/step - loss: 0.5910 - accuracy: 0.6784 - val_loss: 0.5868 - val_accuracy: 0.6848
# Epoch 25/30
# 570/570 [==============================] - 0s 753us/step - loss: 0.5908 - accuracy: 0.6766 - val_loss: 0.5871 - val_accuracy: 0.6818
# Epoch 26/30
# 570/570 [==============================] - 0s 730us/step - loss: 0.5896 - accuracy: 0.6820 - val_loss: 0.5833 - val_accuracy: 0.6878
# Epoch 27/30
# 570/570 [==============================] - 0s 732us/step - loss: 0.5871 - accuracy: 0.6822 - val_loss: 0.5820 - val_accuracy: 0.6863
# Epoch 28/30
# 570/570 [==============================] - 0s 728us/step - loss: 0.5904 - accuracy: 0.6789 - val_loss: 0.5842 - val_accuracy: 0.6860
# Epoch 29/30
# 570/570 [==============================] - 0s 731us/step - loss: 0.5867 - accuracy: 0.6795 - val_loss: 0.5829 - val_accuracy: 0.6881
# Epoch 30/30
# 570/570 [==============================] - 0s 749us/step - loss: 0.5870 - accuracy: 0.6801 - val_loss: 0.5825 - val_accuracy: 0.6884

# %%
from sklearn.metrics import accuracy_score
y_predict = model.predict(X_test_filtered)
print('Accuracy :', accuracy_score(y_predict.round(), y_test))
# Out:
# 223/223 [==============================] - 0s 446us/step
# Accuracy : 0.7085031623330991

# %%
df_roi = X_test.copy()
df_roi["y_predict_proba"] = y_predict   #all rows, first column = prediction score for winner 1 
df_roi["y_predict"] = y_predict.round()
df_roi["y_test"] = y_test

df_roi["proba_bookmaker"] = (1/df_roi.player1_oddsB365).round()
df_roi[["player1_name","player1_oddsB365","player2_name","player2_oddsB365", "winner_player1","proba_bookmaker","y_predict","y_predict_proba"]]
# Out:
#           player1_name  player1_oddsB365          player2_name  \
# 18040    Kei Nishikori              2.25           Juan Monaco
# 38319     David Goffin              1.20  Albert Ramos-Vinolas
# 18243    Jeremy Chardy              1.53        Potito Starace
# 26696        Dudi Sela              8.00          Gilles Simon
# 26064   Lleyton Hewitt              3.75          Andy Roddick
# ...                ...               ...                   ...
# 45683     Daniel Evans              1.66       Karen Khachanov
# 40777    Steve Johnson              1.72      Adrian Mannarino
# 12603  Fabrice Santoro              3.50         Tomas Berdych
# 28990      Marin Cilic              1.28         Pablo Andujar
# 41432      Jiri Vesely              1.57  Nikoloz Basilashvili
#
#        player2_oddsB365  winner_player1  proba_bookmaker  y_predict  \
# 18040              1.57               1              0.0        0.0
# 38319              4.50               1              1.0        0.0
# 18243              2.37               1              1.0        0.0
# 26696              1.08               0              0.0        0.0
# 26064              1.25               1              0.0        0.0
# ...                 ...             ...              ...        ...
# 45683              2.10               1              1.0        0.0
# 40777              2.00               1              1.0        0.0
# 12603              1.28               0              0.0        0.0
# 28990              3.50               0              1.0        0.0
# 41432              2.37               1              1.0        0.0
#
#        y_predict_proba
# 18040         0.412435
# 38319         0.255402
# 18243         0.379117
# 26696         0.086660
# 26064         0.240141
# ...                ...
# 45683         0.390077
# 40777         0.400059
# 12603         0.240636
# 28990         0.303426
# 41432         0.375520
#
# [7115 rows x 8 columns]

# %%
# ROI return of investment on all games
print("We bet 1€ on all test matches")
df_roi = X_test.copy()
df_roi["y_predict_proba"] = y_predict   #all rows, first column = prediction score for winner 1 
df_roi["y_predict"] = y_predict.round()
df_roi["y_test"] = y_test
df_roi["proba_bookmaker"] = (1/df_roi.player1_oddsB365).round()

df_roi= df_roi.loc[df_roi["y_predict_proba"]>0.4]

money_invested=df_roi.shape[0]

money_won = 0.0
for index, row in df_roi.iterrows():
    if (((row.player1_oddsB365 > row.player2_oddsB365) & (row.winner_player1 ==1) & (row.y_predict == 1) ) | ((row.player1_oddsB365 < row.player2_oddsB365) & (row.winner_player1 ==1) & (row.y_predict == 0))) :
        if row.winner_player1 == 0:
            money_won += row.player2_oddsB365
        else:
            money_won += row.player1_oddsB365

print("money spent:", money_invested,"€")
print("money won:",round(money_won,2),"€")
print("TOTAL:", round(money_won - money_invested, 2),"€")
print("ROI:", round(money_won*100/money_invested,2),"%")
# Out:
# We bet 1€ on all test matches
# money spent: 1431 €
# money won: 459.21 €
# TOTAL: -971.79 €
# ROI: 32.09 %
