# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

df=pd.read_csv("./data/training_dataset.csv",low_memory=False)
df.match_date = df.match_date.apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))

# %%
df
# Out:
#        player1_name  player1_atprank  player1_games  player1_wins  \
# 0       Harrison R.              481            272           117
# 1          Korda S.               26            126            75
# 2           Paul T.               14            204           111
# 3     Kecmanovic M.               40            210           107
# 4       Bellucci T.              915            380           179
# ...             ...              ...            ...           ...
# 7057       Evans D.               30            251           124
# 7058  Griekspoor T.               37             97            47
# 7059   De Minaur A.               19            272           161
# 7060       Evans D.               30            251           124
# 7061       Evans D.               30            251           124
#
#       player1_loses   player2_name  player2_atprank  player2_games  \
# 0               155       Mager G.               67             59
# 1                51      Kwon S.W.               68            108
# 2                93       Nam J.S.              590              3
# 3               103   Travaglia S.             1024             81
# 4               201    Monteiro T.              121            171
# ...             ...            ...              ...            ...
# 7057            127      Tiafoe F.               10            303
# 7058             50       Fritz T.                9            356
# 7059            111   Tsitsipas S.                5            390
# 7060            127    Dimitrov G.               20            651
# 7061            127  Griekspoor T.               37             97
#
#       player2_wins  player2_loses match_date match_location  \
# 0               24             35 2021-01-07   Delray Beach
# 1               53             55 2021-01-07   Delray Beach
# 2                0              3 2021-01-07   Delray Beach
# 3               27             54 2021-01-07        Antalya
# 4               69            102 2021-01-07   Delray Beach
# ...            ...            ...        ...            ...
# 7057           158            145 2023-08-05     Washington
# 7058           205            151 2023-08-06     Washington
# 7059           264            126 2023-08-06      Los Cabos
# 7060           389            262 2023-08-06     Washington
# 7061            47             50 2023-08-06     Washington
#
#        match_tournament match_surface  match_odd_player1  match_odd_player2  \
# 0     Delray Beach Open          Hard               1.72               2.00
# 1     Delray Beach Open          Hard               1.72               2.00
# 2     Delray Beach Open          Hard               1.12               6.00
# 3          Antalya Open          Hard               1.44               2.62
# 4     Delray Beach Open          Hard               3.00               1.36
# ...                 ...           ...                ...                ...
# 7057          Citi Open          Hard               3.75               1.29
# 7058          Citi Open          Hard               3.50               1.30
# 7059     Los Cabos Open          Hard               3.20               1.36
# 7060          Citi Open          Hard               3.20               1.36
# 7061          Citi Open          Hard               2.00               1.80
#
#       winner_player1
# 0                  0
# 1                  1
# 2                  1
# 3                  0
# 4                  0
# ...              ...
# 7057               1
# 7058               1
# 7059               0
# 7060               1
# 7061               1
#
# [7062 rows x 17 columns]

# %%
df = df.dropna()

# %%
from sklearn.model_selection import train_test_split

X = df[["player1_atprank", "player2_atprank","match_date", "match_odd_player1", "match_odd_player2"]]
y = df.winner_player1

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_test
# Out:
#       player1_atprank  player2_atprank match_date  match_odd_player1  \
# 6417               50              121 2023-05-30               1.36
# 1707              104              172 2021-07-26               1.40
# 5467             1345              147 2023-02-14               1.44
# 6691              109              125 2023-07-03               2.63
# 3623               29                4 2022-05-13               3.00
# ...               ...              ...        ...                ...
# 6091                6               50 2023-04-20               1.29
# 5102                1                6 2022-11-04               1.44
# 3652              135              118 2022-05-17               2.30
# 1614                4               64 2021-07-17               1.14
# 3078               14                2 2022-02-25               7.00
#
#       match_odd_player2
# 6417               3.20
# 1707               3.00
# 5467               2.75
# 6691               1.50
# 3623               1.40
# ...                 ...
# 6091               3.75
# 5102               2.75
# 3652               1.61
# 1614               5.50
# 3078               1.10
#
# [1406 rows x 5 columns]

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

X_train_filtered = X_train.drop("match_date",axis=1)
X_test_filtered = X_test.drop("match_date",axis=1)
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X_train_filtered, y_train)

#cross_val_score(dtree, X_test, y_test, cv=10)

y_predict = dtree.predict(X_test_filtered)

accuracy_score(y_predict, y_test)
# Out:
# 0.5981507823613087

# %%
# ROI return of investment

print("We bet 1€ on all test matches")
df_roi = X_test.copy()
df_roi["y_predict"] = y_predict
df_roi["y_test"]=y_test

money_invested=df_roi.shape[0]
print("money spent:", money_invested,"€")

money_won = 0.0
for index, row in (df_roi[y_predict == y_test]).iterrows():
    if row.y_predict == 0 :
        money_won += row.match_odd_player2
    else:
        money_won += row.match_odd_player1

print("money won:",round(money_won,2),"€")
print("TOTAL:", round(money_won - money_invested, 2),"€")
print("ROI:", round(money_won*100/money_invested,2),"%")
# Out:
# We bet 1€ on all test matches
# money spent: 1406 €
# money won: 1359.85 €
# TOTAL: -46.15 €
# ROI: 96.72 %

# %%
import matplotlib.pyplot as plt

df_roi = df_roi.sort_values(by='match_date')
dates = df_roi.match_date.unique()
data = []

for date in dates :
    money_won = 0.0
    #test = df_roi.at[df_roi.index[0],"match_date"]
    df_roi_filtered = df_roi.loc[df_roi["match_date"]==date]
    #print(df_roi_filtered)
    money_won-=df_roi_filtered.shape[0]

    for index, row in (df_roi_filtered.loc[df_roi_filtered["y_predict"] == df_roi_filtered["y_test"]]).iterrows():
        if row.y_predict == 0 :
            money_won += row.match_odd_player2
        else:
            money_won += row.match_odd_player1

    data.append(money_won)

dates = dates.astype('datetime64[ns]')

plt.plot_date(pd.to_datetime(dates.date, format='%Y-%m-%d'), data, 'g')
plt.xticks(rotation=70)
plt.show()


d = {'date': dates.date, 
     'money_won': data}
roi = pd.DataFrame(data=d)

# %%
roi.sort_values(by="money_won")
# Out:
#            date  money_won
# 373  2022-08-17      -5.00
# 94   2021-06-01      -4.28
# 14   2021-02-09      -4.09
# 516  2023-05-16      -4.00
# 485  2023-04-04      -3.71
# ..          ...        ...
# 438  2023-01-17       3.99
# 160  2021-08-30       4.02
# 536  2023-06-16       4.64
# 305  2022-05-16       5.77
# 429  2023-01-02       5.95
#
# [573 rows x 2 columns]

# %%
df_roi
# Out:
#       player1_atprank  player2_atprank match_date  match_odd_player1  \
# 6                 267              118 2021-01-07               2.50
# 5                  25              146 2021-01-07               1.61
# 9                 123              157 2021-01-07               1.40
# 8                  55              528 2021-01-07               1.50
# 14                695              304 2021-01-08               1.50
# ...               ...              ...        ...                ...
# 7022              101              115 2023-08-02               1.67
# 7000               82               54 2023-08-02               2.20
# 7032              113              115 2023-08-03               2.10
# 7052                9               44 2023-08-04               1.36
# 7058               37                9 2023-08-06               3.50
#
#       match_odd_player2  y_predict  y_test
# 6                  1.50          0       0
# 5                  2.20          1       1
# 9                  2.75          1       1
# 8                  2.50          1       1
# 14                 2.50          1       1
# ...                 ...        ...     ...
# 7022               2.20          1       0
# 7000               1.67          0       0
# 7032               1.73          0       1
# 7052               3.20          1       1
# 7058               1.30          0       1
#
# [1406 rows x 7 columns]
